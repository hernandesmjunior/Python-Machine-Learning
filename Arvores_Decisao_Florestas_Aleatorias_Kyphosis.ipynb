# %% [markdown]
# # Árvores de Decisão e Florestas Aleatórias #1

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\herna\OneDrive\Python-Data-Science-and-Machine-Learning-Bootcamp\5. Machine Learning\Árvores de decisão e Florestas Aleatórias\kyphosis.csv")

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
# ## Análise Exploratória

# %%
sns.pairplot(df, hue='Kyphosis', palette='inferno')

# %% [markdown]
# ## Criando o modelo de Árvore de Decisão

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis', axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.95      0.82      0.88        22
#      present       0.33      0.67      0.44         3
#
#     accuracy                           0.80        25
#    macro avg       0.64      0.74      0.66        25
# weighted avg       0.87      0.80      0.83        25

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[18  4]
#  [ 1  2]]

# %% [markdown]
# ## Criando modelo de Floresta Aleatória

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test, rfc_pred))
print('\n')
print(confusion_matrix(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.95      0.95      0.95        22
#      present       0.67      0.67      0.67         3
#
#     accuracy                           0.92        25
#    macro avg       0.81      0.81      0.81        25
# weighted avg       0.92      0.92      0.92        25
#
#
#
# [[21  1]
#  [ 1  2]]
